# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('F:/data science/Data/Match.csv')
df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %% [markdown]
# ## Problem Statement
# - 1.Display the count of matches based on the year wise

# %% [markdown]
# ## Description of the problem
# - each season year is grouped and number of matches played in the year is counted using Country_id for all the data
# - count gives equal value for any column with numerical data

# %%
# q1
a=df.groupby('Season_Year')['Country_id'].count()
print(a)
# Out:
# Season_Year
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    60
# Name: Country_id, dtype: int64

# %% [markdown]
# ## Problem Statement
# - Plot a bar graph no. of matches won by each team in the year 2011

# %% [markdown]
# ## Description of the problem
# - data frame is resticted to year 2011 and is grouped by match winners and the number of times each team won is counted using
# - country id
# - Then the data frame is converted into lists of indexes and values
# - then a bar graph is drawn

# %%
# q2
b=df[df['Season_Year']==2011].groupby('match_winner')['Country_id'].count()
plt.figure(figsize=(25,10))
q=b.index.tolist()
w=b.values.tolist()
plt.bar(q,w,color='blue',width=0.5)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Problem Statement
# - Print ManOfMatch count of each player in Hyderabad stadium

# %% [markdown]
# ## Description of the problem.
# - data frame is restricted to hyderabad stadium and grouped by man of the match and the number of times each person won is counted by country id

# %%
b=df[df['City_Name']=='Hyderabad'].groupby('ManOfMach')['Country_id'].count()
b
# Out:
# ManOfMach
# A Mishra             2
# AB Dinda             1
# AT Rayudu            1
# B Kumar              1
# CH Morris            1
# DA Warner            6
# DJ Bravo             1
# DJG Sammy            1
# DW Steyn             3
# G Gambhir            1
# GH Vihari            2
# I Sharma             1
# MJ McClenaghan       1
# MR Marsh             1
# Mandeep Singh        1
# Mustafizur Rahman    1
# PA Patel             1
# PC Valthaty          1
# R Vinay Kumar        1
# SC Ganguly           1
# SE Marsh             1
# SK Raina             2
# SK Trivedi           1
# SL Malinga           1
# UT Yadav             1
# V Kohli              1
# V Sehwag             2
# WP Saha              1
# YK Pathan            2
# Name: Country_id, dtype: int64
